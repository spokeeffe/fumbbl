# %%
import pandas as pd
import requests
import json

# %%
def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

# %%
outcasts = requests.get("https://fumbbl.com/api/team/get/950292")

# %%
jprint(outcasts.json())
# Out:
# {
#     "apothecary": "Yes",
#     "assistantCoaches": 0,
#     "cheerleaders": 0,
#     "coach": {
#         "id": 108685,
#         "name": "sokeeffe"
#     },
#     "fanFactor": 9,
#     "id": 950292,
#     "league": 10455,
#     "name": "Waystone Outcasts",
#     "players": [
#         {
#             "id": 13193460,
#             "injuries": "-av",
#             "name": "Ariel Anstar",
#             "number": 1,
#             "position": "Blitzer",
#             "positionId": 25457,
#             "record": {
#                 "casualties": 8,
#                 "completions": 0,
#                 "interceptions": 0,
#                 "mvps": 2,
#                 "spp": 51,
#                 "touchdowns": 7
#             },
#             "skills": [
#                 "Guard",
#                 "Mighty Blow",
#                 "+AG",
#                 "Dodge"
#             ]
#         },
#         {
#             "id": 12967767,
#             "injuries": "-av",
#             "name": "J\u00e9r\u00f4me Jenfyre",
#             "number": 2,
#             "position": "Blitzer",
#             "positionId": 25457,
#             "record": {
#                 "casualties": 35,
#                 "completions": 0,
#                 "interceptions": 0,
#                 "mvps": 2,
#                 "spp": 92,
#                 "touchdowns": 4
#             },
#             "skills": [
#                 "Mighty Blow",
#                 "Tackle",
#                 "Guard",
#                 "Dodge",
#                 "Juggernaut"
#             ]
#         },
#         {
#             "id": 12967768,
#             "injuries": "-ma,n",
#             "name": "Sarrion Gilqirelle",
#             "number": 3,
#             "position": "Thrower",
#             "positionId": 25455,
#             "record": {
#                 "casualties": 4,
#                 "completions": 0,
#                 "interceptions": 0,
#                 "mvps": 1,
#                 "spp": 124,
#                 "touchdowns": 5
#             },
#             "skills": [
#                 "Dodge",
#                 "+AG",
#                 "+MA",
#                 "Block",
#                 "Side Step"
#             ]
#         },
#         {
#             "id": 13406505,
#             "injuries": "",
#             "name": "Rylee Mareena",
#             "number": 4,
#             "position": "Catcher",
#             "positionId": 25456,
#             "record": {
#                 "casualties": 1,
#                 "completions": 0,
#                 "interceptions": 0,
#                 "mvps": 1,
#                 "spp": 37,
#                 "touchdowns": 10
#             },
#             "skills": [
#                 "Block",
#                 "Side Step",
#                 "Diving Tackle"
#             ]
#         },
#         {
#             "id": 14060266,
#             "injuries": "",
#             "name": "Jennev Moire",
#             "number": 5,
#             "position": "Catcher",
#             "positionId": 25456,
#             "record": {
#                 "casualties": 1,
#                 "completions": 0,
#                 "interceptions": 0,
#                 "mvps": 3,
#                 "spp": 29,
#                 "touchdowns": 4
#             },
#             "skills": [
#                 "Wrestle",
#                 "+MA"
#             ]
#         },
#         {
#             "id": 12973497,
#             "injuries": "-ma,-av,-ag",
#             "name": "Glynvor Chabal",
#             "number": 6,
#             "position": "Lineman",
#             "positionId": 25454,
#             "record": {
#                 "casualties": 6,
#                 "completions": 0,
#                 "interceptions": 0,
#                 "mvps": 2,
#                 "spp": 22,
#                 "touchdowns": 0
#             },
#             "skills": [
#                 "Guard",
#                 "Block"
#             ]
#         },
#         {
#             "id": 13734786,
#             "injuries": "",
#             "name": "Skyler Jet\u00e9ri",
#             "number": 7,
#             "position": "Thrower",
#             "positionId": 25455,
#             "record": {
#                 "casualties": 1,
#                 "completions": 0,
#                 "interceptions": 0,
#                 "mvps": 2,
#                 "spp": 18,
#                 "touchdowns": 0
#             },
#             "skills": [
#                 "Block",
#                 "Leader"
#             ]
#         },
#         {
#             "id": 13734787,
#             "injuries": "",
#             "name": "Eloise Galain",
#             "number": 8,
#             "position": "Catcher",
#             "positionId": 25456,
#             "record": {
#                 "casualties": 1,
#                 "completions": 0,
#                 "interceptions": 0,
#                 "mvps": 3,
#                 "spp": 50,
#                 "touchdowns": 11
#             },
#             "skills": [
#                 "Block",
#                 "Side Step",
#                 "Diving Tackle"
#             ]
#         },
#         {
#             "id": 14175661,
#             "injuries": "m",
#             "name": "Mila Tar\u00e9",
#             "number": 9,
#             "position": "Lineman",
#             "positionId": 25454,
#             "record": {
#                 "casualties": 0,
#                 "completions": 0,
#                 "interceptions": 0,
#                 "mvps": 0,
#                 "spp": 0,
#                 "touchdowns": 0
#             },
#             "skills": []
#         },
#         {
#             "id": 14172335,
#             "injuries": "",
#             "name": "Delari Bleure",
#             "number": 10,
#             "position": "Lineman",
#             "positionId": 25454,
#             "record": {
#                 "casualties": 0,
#                 "completions": 0,
#                 "interceptions": 0,
#                 "mvps": 1,
#                 "spp": 6,
#                 "touchdowns": 0
#             },
#             "skills": [
#                 "Dirty Player"
#             ]
#         },
#         {
#             "id": 13717647,
#             "injuries": "",
#             "name": "Thibaut Bayde",
#             "number": 11,
#             "position": "Lineman",
#             "positionId": 25454,
#             "record": {
#                 "casualties": 2,
#                 "completions": 0,
#                 "interceptions": 0,
#                 "mvps": 1,
#                 "spp": 9,
#                 "touchdowns": 0
#             },
#             "skills": [
#                 "Block"
#             ]
#         },
#         {
#             "id": 14175309,
#             "injuries": "-av,m",
#             "name": "Bierson Quid",
#             "number": 12,
#             "position": "Lineman",
#             "positionId": 25454,
#             "record": {
#                 "casualties": 0,
#                 "completions": 0,
#                 "interceptions": 0,
#                 "mvps": 1,
#                 "spp": 5,
#                 "touchdowns": 0
#             },
#             "skills": []
#         },
#         {
#             "id": 13717649,
#             "injuries": "",
#             "name": "Siphanien Perqen",
#             "number": 13,
#             "position": "Lineman",
#             "positionId": 25454,
#             "record": {
#                 "casualties": 2,
#                 "completions": 0,
#                 "interceptions": 0,
#                 "mvps": 5,
#                 "spp": 29,
#                 "touchdowns": 0
#             },
#             "skills": [
#                 "Guard",
#                 "Block"
#             ]
#         },
#         {
#             "id": 14195843,
#             "injuries": "",
#             "name": "Alvarielle Farlee",
#             "number": 14,
#             "position": "Lineman",
#             "positionId": 25454,
#             "record": {
#                 "casualties": 0,
#                 "completions": 0,
#                 "interceptions": 0,
#                 "mvps": 1,
#                 "spp": 5,
#                 "touchdowns": 0
#             },
#             "skills": []
#         }
#     ],
#     "record": {
#         "games": 44,
#         "losses": 14,
#         "ties": 13,
#         "wins": 17
#     },
#     "rerolls": 3,
#     "roster": {
#         "id": 3525,
#         "name": "Half-Elf (CIBBL)"
#     },
#     "ruleset": 432,
#     "status": "Post Match Sequence",
#     "teamValue": 1870000,
#     "treasury": 250000
# }

# %%
sarrion = requests.get("https://fumbbl.com/api/player/get/12967768")

# %%
jprint(sarrion.json())
# Out:
# {
#     "gender": "female",
#     "icon": "/i/654572",
#     "id": 12967768,
#     "injuries": [
#         "Smashed Hip (-MA)",
#         "Gouged Eye (MNG)",
#         "Smashed Knee (NI)"
#     ],
#     "name": "Sarrion Gilqirelle",
#     "number": 3,
#     "portrait": "/i/652309",
#     "position": {
#         "id": 25455,
#         "name": "Thrower"
#     },
#     "skills": [
#         "Sure Hands",
#         "Strong Arm",
#         "Pass",
#         "Dodge",
#         "+AG",
#         "+MA",
#         "Block",
#         "Side Step"
#     ],
#     "statistics": {
#         "blocks": 69,
#         "casualties": 4,
#         "completions": 96,
#         "fouls": 1,
#         "games": 41,
#         "interceptions": 0,
#         "mvp": 1,
#         "passing": 356,
#         "rushing": 326,
#         "spp": 124,
#         "touchdowns": 5
#     },
#     "status": "Active",
#     "teamId": 950292
# }

# %%
sarrion.json()["skills"]
# Out:
# ['Sure Hands',
#  'Strong Arm',
#  'Pass',
#  'Dodge',
#  '+AG',
#  '+MA',
#  'Block',
#  'Side Step']

# %%
df = pd.json_normalize(sarrion.json())

# %%
df.head()
# Out:
#          id  teamId  status  number                name  gender   portrait  \
# 0  12967768  950292  Active       3  Sarrion Gilqirelle  female  /i/652309
#
#         icon                                             skills  \
# 0  /i/654572  [Sure Hands, Strong Arm, Pass, Dodge, +AG, +MA...
#
#                                             injuries  ...  \
# 0  [Smashed Hip (-MA), Gouged Eye (MNG), Smashed ...  ...
#
#    statistics.completions statistics.touchdowns  statistics.interceptions  \
# 0                      96                     5                         0
#
#    statistics.casualties  statistics.mvp  statistics.passing  \
# 0                      4               1                 356
#
#    statistics.rushing  statistics.blocks  statistics.fouls  statistics.games
# 0                 326                 69                 1                41
#
# [1 rows x 23 columns]

# %%
# Get list of players given a team id
outcasts.json()["players"][1]["id"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-b4136ba8b13c> in <module>
#       1 # Get list of players given a team id
# ----> 2 outcasts.json()["players"]["id"]
#
# TypeError: list indices must be integers or slices, not str

# %%
def get_players_ids_from_team(team_id):
    api_url = f"https://fumbbl.com/api/team/get/{team_id}"
    print(api_url)
    player_id_list = []
    team = requests.get(api_url)
    for player in team.json()["players"]:
        player_id_list.append(player.get('id'))
        
    return player_id_list

# %%
get_players_ids_from_team(950292)
# Out:
# https://fumbbl.com/api/team/get/950292
# [13193460,
#  12967767,
#  12967768,
#  13406505,
#  14060266,
#  12973497,
#  13734786,
#  13734787,
#  14175661,
#  14172335,
#  13717647,
#  14175309,
#  13717649,
#  14195843]
